# %%
import pandas as pd

# %%
# Read CSV files
file_name = 'summary.txt'
columnNames = ["Operation","Key","Value"]
df = pd.read_csv(file_name,names = columnNames)
# df.columns=["Operation","Key","Value"] Deletes the first row and adds title

# %%
df
# Out:
#                          Operation                         Key         Value
# 0                        [OVERALL]                 RunTime(ms)   1435.000000
# 1                        [OVERALL]         Throughput(ops/sec)   3484.320557
# 2          [TOTAL_GCS_PS_Scavenge]                       Count      5.000000
# 3      [TOTAL_GC_TIME_PS_Scavenge]                    Time(ms)     19.000000
# 4    [TOTAL_GC_TIME_%_PS_Scavenge]                     Time(%)      1.324042
# 5         [TOTAL_GCS_PS_MarkSweep]                       Count      0.000000
# 6     [TOTAL_GC_TIME_PS_MarkSweep]                    Time(ms)      0.000000
# 7   [TOTAL_GC_TIME_%_PS_MarkSweep]                     Time(%)      0.000000
# 8                      [TOTAL_GCs]                       Count      5.000000
# 9                  [TOTAL_GC_TIME]                    Time(ms)     19.000000
# 10               [TOTAL_GC_TIME_%]                     Time(%)      1.324042
# 11                          [READ]                  Operations   4757.000000
# 12                          [READ]          AverageLatency(us)    391.713475
# 13                          [READ]              MinLatency(us)    150.000000
# 14                          [READ]              MaxLatency(us)  56863.000000
# 15                          [READ]   95thPercentileLatency(us)    824.000000
# 16                          [READ]   99thPercentileLatency(us)   1997.000000
# 17                          [READ]                   Return=OK   4757.000000
# 18                       [CLEANUP]                  Operations      2.000000
# 19                       [CLEANUP]          AverageLatency(us)    918.500000
# 20                       [CLEANUP]              MinLatency(us)      5.000000
# 21                       [CLEANUP]              MaxLatency(us)   1832.000000
# 22                       [CLEANUP]   95thPercentileLatency(us)   1832.000000
# 23                       [CLEANUP]   99thPercentileLatency(us)   1832.000000
# 24                        [UPDATE]                  Operations    243.000000
# 25                        [UPDATE]          AverageLatency(us)    694.983539
# 26                        [UPDATE]              MinLatency(us)    290.000000
# 27                        [UPDATE]              MaxLatency(us)  31423.000000
# 28                        [UPDATE]   95thPercentileLatency(us)   1021.000000
# 29                        [UPDATE]   99thPercentileLatency(us)   2449.000000
# 30                        [UPDATE]                   Return=OK    243.000000

# %%
df['Title'] = df["Operation"]+df["Key"]

# %%
df
# Out:
#                          Operation                         Key         Value  \
# 0                        [OVERALL]                 RunTime(ms)   1435.000000
# 1                        [OVERALL]         Throughput(ops/sec)   3484.320557
# 2          [TOTAL_GCS_PS_Scavenge]                       Count      5.000000
# 3      [TOTAL_GC_TIME_PS_Scavenge]                    Time(ms)     19.000000
# 4    [TOTAL_GC_TIME_%_PS_Scavenge]                     Time(%)      1.324042
# 5         [TOTAL_GCS_PS_MarkSweep]                       Count      0.000000
# 6     [TOTAL_GC_TIME_PS_MarkSweep]                    Time(ms)      0.000000
# 7   [TOTAL_GC_TIME_%_PS_MarkSweep]                     Time(%)      0.000000
# 8                      [TOTAL_GCs]                       Count      5.000000
# 9                  [TOTAL_GC_TIME]                    Time(ms)     19.000000
# 10               [TOTAL_GC_TIME_%]                     Time(%)      1.324042
# 11                          [READ]                  Operations   4757.000000
# 12                          [READ]          AverageLatency(us)    391.713475
# 13                          [READ]              MinLatency(us)    150.000000
# 14                          [READ]              MaxLatency(us)  56863.000000
# 15                          [READ]   95thPercentileLatency(us)    824.000000
# 16                          [READ]   99thPercentileLatency(us)   1997.000000
# 17                          [READ]                   Return=OK   4757.000000
# 18                       [CLEANUP]                  Operations      2.000000
# 19                       [CLEANUP]          AverageLatency(us)    918.500000
# 20                       [CLEANUP]              MinLatency(us)      5.000000
# 21                       [CLEANUP]              MaxLatency(us)   1832.000000
# 22                       [CLEANUP]   95thPercentileLatency(us)   1832.000000
# 23                       [CLEANUP]   99thPercentileLatency(us)   1832.000000
# 24                        [UPDATE]                  Operations    243.000000
# 25                        [UPDATE]          AverageLatency(us)    694.983539
# 26                        [UPDATE]              MinLatency(us)    290.000000
# 27                        [UPDATE]              MaxLatency(us)  31423.000000
# 28                        [UPDATE]   95thPercentileLatency(us)   1021.000000
# 29                        [UPDATE]   99thPercentileLatency(us)   2449.000000
# 30                        [UPDATE]                   Return=OK    243.000000
#
#                                      Title
# 0                    [OVERALL] RunTime(ms)
# 1            [OVERALL] Throughput(ops/sec)
# 2            [TOTAL_GCS_PS_Scavenge] Count
# 3     [TOTAL_GC_TIME_PS_Scavenge] Time(ms)
# 4    [TOTAL_GC_TIME_%_PS_Scavenge] Time(%)
# 5           [TOTAL_GCS_PS_MarkSweep] Count
# 6    [TOTAL_GC_TIME_PS_MarkSweep] Time(ms)
# 7   [TOTAL_GC_TIME_%_PS_MarkSweep] Time(%)
# 8                        [TOTAL_GCs] Count
# 9                 [TOTAL_GC_TIME] Time(ms)
# 10               [TOTAL_GC_TIME_%] Time(%)
# 11                       [READ] Operations
# 12               [READ] AverageLatency(us)
# 13                   [READ] MinLatency(us)
# 14                   [READ] MaxLatency(us)
# 15        [READ] 95thPercentileLatency(us)
# 16        [READ] 99thPercentileLatency(us)
# 17                        [READ] Return=OK
# 18                    [CLEANUP] Operations
# 19            [CLEANUP] AverageLatency(us)
# 20                [CLEANUP] MinLatency(us)
# 21                [CLEANUP] MaxLatency(us)
# 22     [CLEANUP] 95thPercentileLatency(us)
# 23     [CLEANUP] 99thPercentileLatency(us)
# 24                     [UPDATE] Operations
# 25             [UPDATE] AverageLatency(us)
# 26                 [UPDATE] MinLatency(us)
# 27                 [UPDATE] MaxLatency(us)
# 28      [UPDATE] 95thPercentileLatency(us)
# 29      [UPDATE] 99thPercentileLatency(us)
# 30                      [UPDATE] Return=OK

# %%
df.set_index("Title",inplace=True)

# %%
df
# Out:
#                                                              Operation  \
# Title
# [OVERALL] RunTime(ms)                                        [OVERALL]
# [OVERALL] Throughput(ops/sec)                                [OVERALL]
# [TOTAL_GCS_PS_Scavenge] Count                  [TOTAL_GCS_PS_Scavenge]
# [TOTAL_GC_TIME_PS_Scavenge] Time(ms)       [TOTAL_GC_TIME_PS_Scavenge]
# [TOTAL_GC_TIME_%_PS_Scavenge] Time(%)    [TOTAL_GC_TIME_%_PS_Scavenge]
# [TOTAL_GCS_PS_MarkSweep] Count                [TOTAL_GCS_PS_MarkSweep]
# [TOTAL_GC_TIME_PS_MarkSweep] Time(ms)     [TOTAL_GC_TIME_PS_MarkSweep]
# [TOTAL_GC_TIME_%_PS_MarkSweep] Time(%)  [TOTAL_GC_TIME_%_PS_MarkSweep]
# [TOTAL_GCs] Count                                          [TOTAL_GCs]
# [TOTAL_GC_TIME] Time(ms)                               [TOTAL_GC_TIME]
# [TOTAL_GC_TIME_%] Time(%)                            [TOTAL_GC_TIME_%]
# [READ] Operations                                               [READ]
# [READ] AverageLatency(us)                                       [READ]
# [READ] MinLatency(us)                                           [READ]
# [READ] MaxLatency(us)                                           [READ]
# [READ] 95thPercentileLatency(us)                                [READ]
# [READ] 99thPercentileLatency(us)                                [READ]
# [READ] Return=OK                                                [READ]
# [CLEANUP] Operations                                         [CLEANUP]
# [CLEANUP] AverageLatency(us)                                 [CLEANUP]
# [CLEANUP] MinLatency(us)                                     [CLEANUP]
# [CLEANUP] MaxLatency(us)                                     [CLEANUP]
# [CLEANUP] 95thPercentileLatency(us)                          [CLEANUP]
# [CLEANUP] 99thPercentileLatency(us)                          [CLEANUP]
# [UPDATE] Operations                                           [UPDATE]
# [UPDATE] AverageLatency(us)                                   [UPDATE]
# [UPDATE] MinLatency(us)                                       [UPDATE]
# [UPDATE] MaxLatency(us)                                       [UPDATE]
# [UPDATE] 95thPercentileLatency(us)                            [UPDATE]
# [UPDATE] 99thPercentileLatency(us)                            [UPDATE]
# [UPDATE] Return=OK                                            [UPDATE]
#
#                                                                Key  \
# Title
# [OVERALL] RunTime(ms)                                  RunTime(ms)
# [OVERALL] Throughput(ops/sec)                  Throughput(ops/sec)
# [TOTAL_GCS_PS_Scavenge] Count                                Count
# [TOTAL_GC_TIME_PS_Scavenge] Time(ms)                      Time(ms)
# [TOTAL_GC_TIME_%_PS_Scavenge] Time(%)                      Time(%)
# [TOTAL_GCS_PS_MarkSweep] Count                               Count
# [TOTAL_GC_TIME_PS_MarkSweep] Time(ms)                     Time(ms)
# [TOTAL_GC_TIME_%_PS_MarkSweep] Time(%)                     Time(%)
# [TOTAL_GCs] Count                                            Count
# [TOTAL_GC_TIME] Time(ms)                                  Time(ms)
# [TOTAL_GC_TIME_%] Time(%)                                  Time(%)
# [READ] Operations                                       Operations
# [READ] AverageLatency(us)                       AverageLatency(us)
# [READ] MinLatency(us)                               MinLatency(us)
# [READ] MaxLatency(us)                               MaxLatency(us)
# [READ] 95thPercentileLatency(us)         95thPercentileLatency(us)
# [READ] 99thPercentileLatency(us)         99thPercentileLatency(us)
# [READ] Return=OK                                         Return=OK
# [CLEANUP] Operations                                    Operations
# [CLEANUP] AverageLatency(us)                    AverageLatency(us)
# [CLEANUP] MinLatency(us)                            MinLatency(us)
# [CLEANUP] MaxLatency(us)                            MaxLatency(us)
# [CLEANUP] 95thPercentileLatency(us)      95thPercentileLatency(us)
# [CLEANUP] 99thPercentileLatency(us)      99thPercentileLatency(us)
# [UPDATE] Operations                                     Operations
# [UPDATE] AverageLatency(us)                     AverageLatency(us)
# [UPDATE] MinLatency(us)                             MinLatency(us)
# [UPDATE] MaxLatency(us)                             MaxLatency(us)
# [UPDATE] 95thPercentileLatency(us)       95thPercentileLatency(us)
# [UPDATE] 99thPercentileLatency(us)       99thPercentileLatency(us)
# [UPDATE] Return=OK                                       Return=OK
#
#                                                Value
# Title
# [OVERALL] RunTime(ms)                    1435.000000
# [OVERALL] Throughput(ops/sec)            3484.320557
# [TOTAL_GCS_PS_Scavenge] Count               5.000000
# [TOTAL_GC_TIME_PS_Scavenge] Time(ms)       19.000000
# [TOTAL_GC_TIME_%_PS_Scavenge] Time(%)       1.324042
# [TOTAL_GCS_PS_MarkSweep] Count              0.000000
# [TOTAL_GC_TIME_PS_MarkSweep] Time(ms)       0.000000
# [TOTAL_GC_TIME_%_PS_MarkSweep] Time(%)      0.000000
# [TOTAL_GCs] Count                           5.000000
# [TOTAL_GC_TIME] Time(ms)                   19.000000
# [TOTAL_GC_TIME_%] Time(%)                   1.324042
# [READ] Operations                        4757.000000
# [READ] AverageLatency(us)                 391.713475
# [READ] MinLatency(us)                     150.000000
# [READ] MaxLatency(us)                   56863.000000
# [READ] 95thPercentileLatency(us)          824.000000
# [READ] 99thPercentileLatency(us)         1997.000000
# [READ] Return=OK                         4757.000000
# [CLEANUP] Operations                        2.000000
# [CLEANUP] AverageLatency(us)              918.500000
# [CLEANUP] MinLatency(us)                    5.000000
# [CLEANUP] MaxLatency(us)                 1832.000000
# [CLEANUP] 95thPercentileLatency(us)      1832.000000
# [CLEANUP] 99thPercentileLatency(us)      1832.000000
# [UPDATE] Operations                       243.000000
# [UPDATE] AverageLatency(us)               694.983539
# [UPDATE] MinLatency(us)                   290.000000
# [UPDATE] MaxLatency(us)                 31423.000000
# [UPDATE] 95thPercentileLatency(us)       1021.000000
# [UPDATE] 99thPercentileLatency(us)       2449.000000
# [UPDATE] Return=OK                        243.000000

# %%
dfnew = df.drop([df.columns[0],df.columns[1]], axis=1)

# %%
dfnew = dfnew.loc[columns]

# %%
dfnew.to_dict()['Value']
dfnewValues = dfnew.to_dict()['Value']

# %%
dfnewValues
# Out:
# {'[OVERALL] RunTime(ms)': 1435.0,
#  '[OVERALL] Throughput(ops/sec)': 3484.320557491289,
#  '[READ] Operations': 4757.0,
#  '[READ] AverageLatency(us)': 391.7134748791255,
#  '[READ] MinLatency(us)': 150.0,
#  '[READ] MaxLatency(us)': 56863.0,
#  '[READ] 95thPercentileLatency(us)': 824.0,
#  '[READ] 99thPercentileLatency(us)': 1997.0,
#  '[READ] Return=OK': 4757.0,
#  '[CLEANUP] Operations': 2.0,
#  '[CLEANUP] AverageLatency(us)': 918.5,
#  '[CLEANUP] MinLatency(us)': 5.0,
#  '[CLEANUP] MaxLatency(us)': 1832.0,
#  '[CLEANUP] 95thPercentileLatency(us)': 1832.0,
#  '[CLEANUP] 99thPercentileLatency(us)': 1832.0,
#  '[UPDATE] Operations': 243.0,
#  '[UPDATE] AverageLatency(us)': 694.9835390946503,
#  '[UPDATE] MinLatency(us)': 290.0,
#  '[UPDATE] MaxLatency(us)': 31423.0,
#  '[UPDATE] 95thPercentileLatency(us)': 1021.0,
#  '[UPDATE] 99thPercentileLatency(us)': 2449.0,
#  '[UPDATE] Return=OK': 243.0}

# %%
dfnew
# Out:
#                                             Value
# Title
# [OVERALL] RunTime(ms)                 1435.000000
# [OVERALL] Throughput(ops/sec)         3484.320557
# [READ] Operations                     4757.000000
# [READ] AverageLatency(us)              391.713475
# [READ] MinLatency(us)                  150.000000
# [READ] MaxLatency(us)                56863.000000
# [READ] 95thPercentileLatency(us)       824.000000
# [READ] 99thPercentileLatency(us)      1997.000000
# [READ] Return=OK                      4757.000000
# [CLEANUP] Operations                     2.000000
# [CLEANUP] AverageLatency(us)           918.500000
# [CLEANUP] MinLatency(us)                 5.000000
# [CLEANUP] MaxLatency(us)              1832.000000
# [CLEANUP] 95thPercentileLatency(us)   1832.000000
# [CLEANUP] 99thPercentileLatency(us)   1832.000000
# [UPDATE] Operations                    243.000000
# [UPDATE] AverageLatency(us)            694.983539
# [UPDATE] MinLatency(us)                290.000000
# [UPDATE] MaxLatency(us)              31423.000000
# [UPDATE] 95thPercentileLatency(us)    1021.000000
# [UPDATE] 99thPercentileLatency(us)    2449.000000
# [UPDATE] Return=OK                     243.000000

# %%
convert = dfnew.iloc[:,0].to_numpy()

# %%
convert.shape
# Out:
# (22,)

# %%
convert = convert.reshape(1,22)

# %%
dfnewConverted = pd.DataFrame(convert, columns = columns)

# %%
dfobj2 = pd.read_csv("cleaned.csv",index_col=0)

# %%
dfobj2
# Out:
#            [OVERALL] RunTime(ms)  [OVERALL] Throughput(ops/sec)  \
# Couchbase                   2173                    2300.966406
#
#            [READ] Operations  [READ] AverageLatency(us)  \
# Couchbase               4773                 438.252462
#
#            [READ] MinLatency(us)  [READ] MaxLatency(us)  \
# Couchbase                    117                  32239
#
#            [READ] 95thPercentileLatency(us)  [READ] 99thPercentileLatency(us)  \
# Couchbase                              1284                              6679
#
#            [READ] Return=OK  [CLEANUP] Operations  ...  \
# Couchbase              4773                     2  ...
#
#            [CLEANUP] MaxLatency(us)  [CLEANUP] 95thPercentileLatency(us)  \
# Couchbase                         2                                    2
#
#            [CLEANUP] 99thPercentileLatency(us)  [UPDATE] Operations  \
# Couchbase                                    2                  227
#
#            [UPDATE] AverageLatency(us)  [UPDATE] MinLatency(us)  \
# Couchbase                   738.471366                      207
#
#            [UPDATE] MaxLatency(us)  [UPDATE] 95thPercentileLatency(us)  \
# Couchbase                    13295                                2026
#
#            [UPDATE] 99thPercentileLatency(us)  [UPDATE] Return=OK
# Couchbase                                9671                 227
#
# [1 rows x 22 columns]

# %%
dfobj2 = dfobj2.append(result, sort=False)

# %%
result = pd.concat([dfObj,dfnewConverted], sort=False) # First argument has concatenated data

# %%
result
# Out:
#    [OVERALL] RunTime(ms)  [OVERALL] Throughput(ops/sec)  [READ] Operations  \
# 0                 1435.0                    3484.320557             4757.0
#
#    [READ] AverageLatency(us)  [READ] MinLatency(us)  [READ] MaxLatency(us)  \
# 0                 391.713475                  150.0                56863.0
#
#    [READ] 95thPercentileLatency(us)  [READ] 99thPercentileLatency(us)  \
# 0                             824.0                            1997.0
#
#    [READ] Return=OK  [CLEANUP] Operations  ...  [CLEANUP] MaxLatency(us)  \
# 0            4757.0                   2.0  ...                    1832.0
#
#    [CLEANUP] 95thPercentileLatency(us)  [CLEANUP] 99thPercentileLatency(us)  \
# 0                               1832.0                               1832.0
#
#    [UPDATE] Operations  [UPDATE] AverageLatency(us)  [UPDATE] MinLatency(us)  \
# 0                243.0                   694.983539                    290.0
#
#    [UPDATE] MaxLatency(us)  [UPDATE] 95thPercentileLatency(us)  \
# 0                  31423.0                              1021.0
#
#    [UPDATE] 99thPercentileLatency(us)  [UPDATE] Return=OK
# 0                              2449.0               243.0
#
# [1 rows x 22 columns]

# %%
columns = ['[OVERALL] RunTime(ms)',
 '[OVERALL] Throughput(ops/sec)',
 '[READ] Operations',
 '[READ] AverageLatency(us)',
 '[READ] MinLatency(us)',
 '[READ] MaxLatency(us)',
 '[READ] 95thPercentileLatency(us)',
 '[READ] 99thPercentileLatency(us)',
 '[READ] Return=OK',
 '[CLEANUP] Operations',
 '[CLEANUP] AverageLatency(us)',
 '[CLEANUP] MinLatency(us)',
 '[CLEANUP] MaxLatency(us)',
 '[CLEANUP] 95thPercentileLatency(us)',
 '[CLEANUP] 99thPercentileLatency(us)',
 '[UPDATE] Operations',
 '[UPDATE] AverageLatency(us)',
 '[UPDATE] MinLatency(us)',
 '[UPDATE] MaxLatency(us)',
 '[UPDATE] 95thPercentileLatency(us)',
 '[UPDATE] 99thPercentileLatency(us)',
 '[UPDATE] Return=OK']

# %%
# Creating an empty Dataframe with column names only
dfObj = pd.DataFrame(columns=columns)

# %%
dfObj
# Out:
# Empty DataFrame
# Columns: [[OVERALL] RunTime(ms), [OVERALL] Throughput(ops/sec), [READ] Operations, [READ] AverageLatency(us), [READ] MinLatency(us), [READ] MaxLatency(us), [READ] 95thPercentileLatency(us), [READ] 99thPercentileLatency(us), [READ] Return=OK, [CLEANUP] Operations, [CLEANUP] AverageLatency(us), [CLEANUP] MinLatency(us), [CLEANUP] MaxLatency(us), [CLEANUP] 95thPercentileLatency(us), [CLEANUP] 99thPercentileLatency(us), [UPDATE] Operations, [UPDATE] AverageLatency(us), [UPDATE] MinLatency(us), [UPDATE] MaxLatency(us), [UPDATE] 95thPercentileLatency(us), [UPDATE] 99thPercentileLatency(us), [UPDATE] Return=OK]
# Index: []
#
# [0 rows x 22 columns]

# %%
dfobj2
# Out:
#            [OVERALL] RunTime(ms)  [OVERALL] Throughput(ops/sec)  \
# Couchbase                 2173.0                    2300.966406
# 0                         1435.0                    3484.320557
#
#            [READ] Operations  [READ] AverageLatency(us)  \
# Couchbase             4773.0                 438.252462
# 0                     4757.0                 391.713475
#
#            [READ] MinLatency(us)  [READ] MaxLatency(us)  \
# Couchbase                  117.0                32239.0
# 0                          150.0                56863.0
#
#            [READ] 95thPercentileLatency(us)  [READ] 99thPercentileLatency(us)  \
# Couchbase                            1284.0                            6679.0
# 0                                     824.0                            1997.0
#
#            [READ] Return=OK  [CLEANUP] Operations  ...  \
# Couchbase            4773.0                   2.0  ...
# 0                    4757.0                   2.0  ...
#
#            [CLEANUP] MaxLatency(us)  [CLEANUP] 95thPercentileLatency(us)  \
# Couchbase                       2.0                                  2.0
# 0                            1832.0                               1832.0
#
#            [CLEANUP] 99thPercentileLatency(us)  [UPDATE] Operations  \
# Couchbase                                  2.0                227.0
# 0                                       1832.0                243.0
#
#            [UPDATE] AverageLatency(us)  [UPDATE] MinLatency(us)  \
# Couchbase                   738.471366                    207.0
# 0                           694.983539                    290.0
#
#            [UPDATE] MaxLatency(us)  [UPDATE] 95thPercentileLatency(us)  \
# Couchbase                  13295.0                              2026.0
# 0                          31423.0                              1021.0
#
#            [UPDATE] 99thPercentileLatency(us)  [UPDATE] Return=OK
# Couchbase                              9671.0               227.0
# 0                                      2449.0               243.0
#
# [2 rows x 22 columns]

# %%
dfobj2.to_csv("newcleaned.csv")

# %%
result.to_csv("newcleaned.csv")

# %%
dfnew2 = dfnew.loc[:,["Run:"]]
