# %%
import pandas as pd

# %%
# Read CSV files
file_name = 'summary.txt'
columnNames = ["Operation","Key","Value"]
df = pd.read_csv(file_name,names = columnNames)
# df.columns=["Operation","Key","Value"] Deletes the first row and adds title

# %%
df
# Out:
#                          Operation                         Key         Value
# 0                        [OVERALL]                 RunTime(ms)   1493.000000
# 1                        [OVERALL]         Throughput(ops/sec)   3348.961822
# 2          [TOTAL_GCS_PS_Scavenge]                       Count      5.000000
# 3      [TOTAL_GC_TIME_PS_Scavenge]                    Time(ms)     24.000000
# 4    [TOTAL_GC_TIME_%_PS_Scavenge]                     Time(%)      1.607502
# 5         [TOTAL_GCS_PS_MarkSweep]                       Count      0.000000
# 6     [TOTAL_GC_TIME_PS_MarkSweep]                    Time(ms)      0.000000
# 7   [TOTAL_GC_TIME_%_PS_MarkSweep]                     Time(%)      0.000000
# 8                      [TOTAL_GCs]                       Count      5.000000
# 9                  [TOTAL_GC_TIME]                    Time(ms)     24.000000
# 10               [TOTAL_GC_TIME_%]                     Time(%)      1.607502
# 11                          [READ]                  Operations   4734.000000
# 12                          [READ]          AverageLatency(us)    401.171103
# 13                          [READ]              MinLatency(us)    142.000000
# 14                          [READ]              MaxLatency(us)  60223.000000
# 15                          [READ]   95thPercentileLatency(us)    838.000000
# 16                          [READ]   99thPercentileLatency(us)   2339.000000
# 17                          [READ]                   Return=OK   4734.000000
# 18                       [CLEANUP]                  Operations      2.000000
# 19                       [CLEANUP]          AverageLatency(us)   2847.500000
# 20                       [CLEANUP]              MinLatency(us)      5.000000
# 21                       [CLEANUP]              MaxLatency(us)   5691.000000
# 22                       [CLEANUP]   95thPercentileLatency(us)   5691.000000
# 23                       [CLEANUP]   99thPercentileLatency(us)   5691.000000
# 24                        [INSERT]                  Operations    266.000000
# 25                        [INSERT]          AverageLatency(us)    642.853383
# 26                        [INSERT]              MinLatency(us)    233.000000
# 27                        [INSERT]              MaxLatency(us)  10351.000000
# 28                        [INSERT]   95thPercentileLatency(us)   1181.000000
# 29                        [INSERT]   99thPercentileLatency(us)   3189.000000
# 30                        [INSERT]                   Return=OK    266.000000

# %%
df['Title'] = df["Operation"]+df["Key"]

# %%
df
# Out:
#                          Operation                         Key         Value  \
# 0                        [OVERALL]                 RunTime(ms)   1493.000000
# 1                        [OVERALL]         Throughput(ops/sec)   3348.961822
# 2          [TOTAL_GCS_PS_Scavenge]                       Count      5.000000
# 3      [TOTAL_GC_TIME_PS_Scavenge]                    Time(ms)     24.000000
# 4    [TOTAL_GC_TIME_%_PS_Scavenge]                     Time(%)      1.607502
# 5         [TOTAL_GCS_PS_MarkSweep]                       Count      0.000000
# 6     [TOTAL_GC_TIME_PS_MarkSweep]                    Time(ms)      0.000000
# 7   [TOTAL_GC_TIME_%_PS_MarkSweep]                     Time(%)      0.000000
# 8                      [TOTAL_GCs]                       Count      5.000000
# 9                  [TOTAL_GC_TIME]                    Time(ms)     24.000000
# 10               [TOTAL_GC_TIME_%]                     Time(%)      1.607502
# 11                          [READ]                  Operations   4734.000000
# 12                          [READ]          AverageLatency(us)    401.171103
# 13                          [READ]              MinLatency(us)    142.000000
# 14                          [READ]              MaxLatency(us)  60223.000000
# 15                          [READ]   95thPercentileLatency(us)    838.000000
# 16                          [READ]   99thPercentileLatency(us)   2339.000000
# 17                          [READ]                   Return=OK   4734.000000
# 18                       [CLEANUP]                  Operations      2.000000
# 19                       [CLEANUP]          AverageLatency(us)   2847.500000
# 20                       [CLEANUP]              MinLatency(us)      5.000000
# 21                       [CLEANUP]              MaxLatency(us)   5691.000000
# 22                       [CLEANUP]   95thPercentileLatency(us)   5691.000000
# 23                       [CLEANUP]   99thPercentileLatency(us)   5691.000000
# 24                        [INSERT]                  Operations    266.000000
# 25                        [INSERT]          AverageLatency(us)    642.853383
# 26                        [INSERT]              MinLatency(us)    233.000000
# 27                        [INSERT]              MaxLatency(us)  10351.000000
# 28                        [INSERT]   95thPercentileLatency(us)   1181.000000
# 29                        [INSERT]   99thPercentileLatency(us)   3189.000000
# 30                        [INSERT]                   Return=OK    266.000000
#
#                                      Title
# 0                    [OVERALL] RunTime(ms)
# 1            [OVERALL] Throughput(ops/sec)
# 2            [TOTAL_GCS_PS_Scavenge] Count
# 3     [TOTAL_GC_TIME_PS_Scavenge] Time(ms)
# 4    [TOTAL_GC_TIME_%_PS_Scavenge] Time(%)
# 5           [TOTAL_GCS_PS_MarkSweep] Count
# 6    [TOTAL_GC_TIME_PS_MarkSweep] Time(ms)
# 7   [TOTAL_GC_TIME_%_PS_MarkSweep] Time(%)
# 8                        [TOTAL_GCs] Count
# 9                 [TOTAL_GC_TIME] Time(ms)
# 10               [TOTAL_GC_TIME_%] Time(%)
# 11                       [READ] Operations
# 12               [READ] AverageLatency(us)
# 13                   [READ] MinLatency(us)
# 14                   [READ] MaxLatency(us)
# 15        [READ] 95thPercentileLatency(us)
# 16        [READ] 99thPercentileLatency(us)
# 17                        [READ] Return=OK
# 18                    [CLEANUP] Operations
# 19            [CLEANUP] AverageLatency(us)
# 20                [CLEANUP] MinLatency(us)
# 21                [CLEANUP] MaxLatency(us)
# 22     [CLEANUP] 95thPercentileLatency(us)
# 23     [CLEANUP] 99thPercentileLatency(us)
# 24                     [INSERT] Operations
# 25             [INSERT] AverageLatency(us)
# 26                 [INSERT] MinLatency(us)
# 27                 [INSERT] MaxLatency(us)
# 28      [INSERT] 95thPercentileLatency(us)
# 29      [INSERT] 99thPercentileLatency(us)
# 30                      [INSERT] Return=OK

# %%
df.set_index("Title",inplace=True)

# %%
df
# Out:
#                                                              Operation  \
# Title
# [OVERALL] RunTime(ms)                                        [OVERALL]
# [OVERALL] Throughput(ops/sec)                                [OVERALL]
# [TOTAL_GCS_PS_Scavenge] Count                  [TOTAL_GCS_PS_Scavenge]
# [TOTAL_GC_TIME_PS_Scavenge] Time(ms)       [TOTAL_GC_TIME_PS_Scavenge]
# [TOTAL_GC_TIME_%_PS_Scavenge] Time(%)    [TOTAL_GC_TIME_%_PS_Scavenge]
# [TOTAL_GCS_PS_MarkSweep] Count                [TOTAL_GCS_PS_MarkSweep]
# [TOTAL_GC_TIME_PS_MarkSweep] Time(ms)     [TOTAL_GC_TIME_PS_MarkSweep]
# [TOTAL_GC_TIME_%_PS_MarkSweep] Time(%)  [TOTAL_GC_TIME_%_PS_MarkSweep]
# [TOTAL_GCs] Count                                          [TOTAL_GCs]
# [TOTAL_GC_TIME] Time(ms)                               [TOTAL_GC_TIME]
# [TOTAL_GC_TIME_%] Time(%)                            [TOTAL_GC_TIME_%]
# [READ] Operations                                               [READ]
# [READ] AverageLatency(us)                                       [READ]
# [READ] MinLatency(us)                                           [READ]
# [READ] MaxLatency(us)                                           [READ]
# [READ] 95thPercentileLatency(us)                                [READ]
# [READ] 99thPercentileLatency(us)                                [READ]
# [READ] Return=OK                                                [READ]
# [CLEANUP] Operations                                         [CLEANUP]
# [CLEANUP] AverageLatency(us)                                 [CLEANUP]
# [CLEANUP] MinLatency(us)                                     [CLEANUP]
# [CLEANUP] MaxLatency(us)                                     [CLEANUP]
# [CLEANUP] 95thPercentileLatency(us)                          [CLEANUP]
# [CLEANUP] 99thPercentileLatency(us)                          [CLEANUP]
# [INSERT] Operations                                           [INSERT]
# [INSERT] AverageLatency(us)                                   [INSERT]
# [INSERT] MinLatency(us)                                       [INSERT]
# [INSERT] MaxLatency(us)                                       [INSERT]
# [INSERT] 95thPercentileLatency(us)                            [INSERT]
# [INSERT] 99thPercentileLatency(us)                            [INSERT]
# [INSERT] Return=OK                                            [INSERT]
#
#                                                                Key  \
# Title
# [OVERALL] RunTime(ms)                                  RunTime(ms)
# [OVERALL] Throughput(ops/sec)                  Throughput(ops/sec)
# [TOTAL_GCS_PS_Scavenge] Count                                Count
# [TOTAL_GC_TIME_PS_Scavenge] Time(ms)                      Time(ms)
# [TOTAL_GC_TIME_%_PS_Scavenge] Time(%)                      Time(%)
# [TOTAL_GCS_PS_MarkSweep] Count                               Count
# [TOTAL_GC_TIME_PS_MarkSweep] Time(ms)                     Time(ms)
# [TOTAL_GC_TIME_%_PS_MarkSweep] Time(%)                     Time(%)
# [TOTAL_GCs] Count                                            Count
# [TOTAL_GC_TIME] Time(ms)                                  Time(ms)
# [TOTAL_GC_TIME_%] Time(%)                                  Time(%)
# [READ] Operations                                       Operations
# [READ] AverageLatency(us)                       AverageLatency(us)
# [READ] MinLatency(us)                               MinLatency(us)
# [READ] MaxLatency(us)                               MaxLatency(us)
# [READ] 95thPercentileLatency(us)         95thPercentileLatency(us)
# [READ] 99thPercentileLatency(us)         99thPercentileLatency(us)
# [READ] Return=OK                                         Return=OK
# [CLEANUP] Operations                                    Operations
# [CLEANUP] AverageLatency(us)                    AverageLatency(us)
# [CLEANUP] MinLatency(us)                            MinLatency(us)
# [CLEANUP] MaxLatency(us)                            MaxLatency(us)
# [CLEANUP] 95thPercentileLatency(us)      95thPercentileLatency(us)
# [CLEANUP] 99thPercentileLatency(us)      99thPercentileLatency(us)
# [INSERT] Operations                                     Operations
# [INSERT] AverageLatency(us)                     AverageLatency(us)
# [INSERT] MinLatency(us)                             MinLatency(us)
# [INSERT] MaxLatency(us)                             MaxLatency(us)
# [INSERT] 95thPercentileLatency(us)       95thPercentileLatency(us)
# [INSERT] 99thPercentileLatency(us)       99thPercentileLatency(us)
# [INSERT] Return=OK                                       Return=OK
#
#                                                Value
# Title
# [OVERALL] RunTime(ms)                    1493.000000
# [OVERALL] Throughput(ops/sec)            3348.961822
# [TOTAL_GCS_PS_Scavenge] Count               5.000000
# [TOTAL_GC_TIME_PS_Scavenge] Time(ms)       24.000000
# [TOTAL_GC_TIME_%_PS_Scavenge] Time(%)       1.607502
# [TOTAL_GCS_PS_MarkSweep] Count              0.000000
# [TOTAL_GC_TIME_PS_MarkSweep] Time(ms)       0.000000
# [TOTAL_GC_TIME_%_PS_MarkSweep] Time(%)      0.000000
# [TOTAL_GCs] Count                           5.000000
# [TOTAL_GC_TIME] Time(ms)                   24.000000
# [TOTAL_GC_TIME_%] Time(%)                   1.607502
# [READ] Operations                        4734.000000
# [READ] AverageLatency(us)                 401.171103
# [READ] MinLatency(us)                     142.000000
# [READ] MaxLatency(us)                   60223.000000
# [READ] 95thPercentileLatency(us)          838.000000
# [READ] 99thPercentileLatency(us)         2339.000000
# [READ] Return=OK                         4734.000000
# [CLEANUP] Operations                        2.000000
# [CLEANUP] AverageLatency(us)             2847.500000
# [CLEANUP] MinLatency(us)                    5.000000
# [CLEANUP] MaxLatency(us)                 5691.000000
# [CLEANUP] 95thPercentileLatency(us)      5691.000000
# [CLEANUP] 99thPercentileLatency(us)      5691.000000
# [INSERT] Operations                       266.000000
# [INSERT] AverageLatency(us)               642.853383
# [INSERT] MinLatency(us)                   233.000000
# [INSERT] MaxLatency(us)                 10351.000000
# [INSERT] 95thPercentileLatency(us)       1181.000000
# [INSERT] 99thPercentileLatency(us)       3189.000000
# [INSERT] Return=OK                        266.000000

# %%
dfnew = df.drop([df.columns[0],df.columns[1]], axis=1)

# %%
dfnew = dfnew.loc[columns]

# %%
dfnew.to_dict()['Value']
dfnewValues = dfnew.to_dict()['Value']

# %%
dfnewValues
# Out:
# {'[OVERALL] RunTime(ms)': 1493.0,
#  '[OVERALL] Throughput(ops/sec)': 3348.9618218352307,
#  '[READ] Operations': 4734.0,
#  '[READ] AverageLatency(us)': 401.17110266159693,
#  '[READ] MinLatency(us)': 142.0,
#  '[READ] MaxLatency(us)': 60223.0,
#  '[READ] 95thPercentileLatency(us)': 838.0,
#  '[READ] 99thPercentileLatency(us)': 2339.0,
#  '[READ] Return=OK': 4734.0,
#  '[CLEANUP] Operations': 2.0,
#  '[CLEANUP] AverageLatency(us)': 2847.5,
#  '[CLEANUP] MinLatency(us)': 5.0,
#  '[CLEANUP] MaxLatency(us)': 5691.0,
#  '[CLEANUP] 95thPercentileLatency(us)': 5691.0,
#  '[CLEANUP] 99thPercentileLatency(us)': 5691.0,
#  '[INSERT] Operations': 266.0,
#  '[INSERT] AverageLatency(us)': 642.8533834586466,
#  '[INSERT] MinLatency(us)': 233.0,
#  '[INSERT] MaxLatency(us)': 10351.0,
#  '[INSERT] 95thPercentileLatency(us)': 1181.0,
#  '[INSERT] 99thPercentileLatency(us)': 3189.0,
#  '[INSERT] Return=OK': 266.0}

# %%
dfnew
# Out:
#                                             Value
# Title
# [OVERALL] RunTime(ms)                 1493.000000
# [OVERALL] Throughput(ops/sec)         3348.961822
# [READ] Operations                     4734.000000
# [READ] AverageLatency(us)              401.171103
# [READ] MinLatency(us)                  142.000000
# [READ] MaxLatency(us)                60223.000000
# [READ] 95thPercentileLatency(us)       838.000000
# [READ] 99thPercentileLatency(us)      2339.000000
# [READ] Return=OK                      4734.000000
# [CLEANUP] Operations                     2.000000
# [CLEANUP] AverageLatency(us)          2847.500000
# [CLEANUP] MinLatency(us)                 5.000000
# [CLEANUP] MaxLatency(us)              5691.000000
# [CLEANUP] 95thPercentileLatency(us)   5691.000000
# [CLEANUP] 99thPercentileLatency(us)   5691.000000
# [INSERT] Operations                    266.000000
# [INSERT] AverageLatency(us)            642.853383
# [INSERT] MinLatency(us)                233.000000
# [INSERT] MaxLatency(us)              10351.000000
# [INSERT] 95thPercentileLatency(us)    1181.000000
# [INSERT] 99thPercentileLatency(us)    3189.000000
# [INSERT] Return=OK                     266.000000

# %%
convert = dfnew.iloc[:,0].to_numpy()

# %%
convert.shape
# Out:
# (22,)

# %%
convert = convert.reshape(1,22)

# %%
dfnewConverted = pd.DataFrame(convert, columns = columns)

# %%
dfobj2 = pd.read_csv("cleaned.csv",index_col=0)

# %%
dfobj2
# Out:
#            [OVERALL] RunTime(ms)  [OVERALL] Throughput(ops/sec)  \
# Couchbase                   2141                     2335.35731
#
#            [READ] Operations  [READ] AverageLatency(us)  \
# Couchbase               4746                 465.676991
#
#            [READ] MinLatency(us)  [READ] MaxLatency(us)  \
# Couchbase                    100                  28143
#
#            [READ] 95thPercentileLatency(us)  [READ] 99thPercentileLatency(us)  \
# Couchbase                              1315                              5007
#
#            [READ] Return=OK  [CLEANUP] Operations  ...  \
# Couchbase              4746                     2  ...
#
#            [CLEANUP] MaxLatency(us)  [CLEANUP] 95thPercentileLatency(us)  \
# Couchbase                         1                                    1
#
#            [CLEANUP] 99thPercentileLatency(us)  [INSERT] Operations  \
# Couchbase                                    1                  254
#
#            [INSERT] AverageLatency(us)  [INSERT] MinLatency(us)  \
# Couchbase                   852.822835                      254
#
#            [INSERT] MaxLatency(us)  [INSERT] 95thPercentileLatency(us)  \
# Couchbase                    13607                                1975
#
#            [INSERT] 99thPercentileLatency(us)  [INSERT] Return=OK
# Couchbase                                5207                 254
#
# [1 rows x 22 columns]

# %%
dfobj2 = dfobj2.append(result, sort=False)

# %%
result = pd.concat([dfObj,dfnewConverted], sort=False) # First argument has concatenated data

# %%
result
# Out:
#    [OVERALL] RunTime(ms)  [OVERALL] Throughput(ops/sec)  [READ] Operations  \
# 0                 1493.0                    3348.961822             4734.0
#
#    [READ] AverageLatency(us)  [READ] MinLatency(us)  [READ] MaxLatency(us)  \
# 0                 401.171103                  142.0                60223.0
#
#    [READ] 95thPercentileLatency(us)  [READ] 99thPercentileLatency(us)  \
# 0                             838.0                            2339.0
#
#    [READ] Return=OK  [CLEANUP] Operations  ...  [CLEANUP] MaxLatency(us)  \
# 0            4734.0                   2.0  ...                    5691.0
#
#    [CLEANUP] 95thPercentileLatency(us)  [CLEANUP] 99thPercentileLatency(us)  \
# 0                               5691.0                               5691.0
#
#    [INSERT] Operations  [INSERT] AverageLatency(us)  [INSERT] MinLatency(us)  \
# 0                266.0                   642.853383                    233.0
#
#    [INSERT] MaxLatency(us)  [INSERT] 95thPercentileLatency(us)  \
# 0                  10351.0                              1181.0
#
#    [INSERT] 99thPercentileLatency(us)  [INSERT] Return=OK
# 0                              3189.0               266.0
#
# [1 rows x 22 columns]

# %%
columns = ['[OVERALL] RunTime(ms)',
 '[OVERALL] Throughput(ops/sec)',
 '[READ] Operations',
 '[READ] AverageLatency(us)',
 '[READ] MinLatency(us)',
 '[READ] MaxLatency(us)',
 '[READ] 95thPercentileLatency(us)',
 '[READ] 99thPercentileLatency(us)',
 '[READ] Return=OK',
 '[CLEANUP] Operations',
 '[CLEANUP] AverageLatency(us)',
 '[CLEANUP] MinLatency(us)',
 '[CLEANUP] MaxLatency(us)',
 '[CLEANUP] 95thPercentileLatency(us)',
 '[CLEANUP] 99thPercentileLatency(us)',
 '[INSERT] Operations',
 '[INSERT] AverageLatency(us)',
 '[INSERT] MinLatency(us)',
 '[INSERT] MaxLatency(us)',
 '[INSERT] 95thPercentileLatency(us)',
 '[INSERT] 99thPercentileLatency(us)',
 '[INSERT] Return=OK']

# %%
# Creating an empty Dataframe with column names only
dfObj = pd.DataFrame(columns=columns)

# %%
dfObj
# Out:
# Empty DataFrame
# Columns: [[OVERALL] RunTime(ms), [OVERALL] Throughput(ops/sec), [READ] Operations, [READ] AverageLatency(us), [READ] MinLatency(us), [READ] MaxLatency(us), [READ] 95thPercentileLatency(us), [READ] 99thPercentileLatency(us), [READ] Return=OK, [CLEANUP] Operations, [CLEANUP] AverageLatency(us), [CLEANUP] MinLatency(us), [CLEANUP] MaxLatency(us), [CLEANUP] 95thPercentileLatency(us), [CLEANUP] 99thPercentileLatency(us), [INSERT] Operations, [INSERT] AverageLatency(us), [INSERT] MinLatency(us), [INSERT] MaxLatency(us), [INSERT] 95thPercentileLatency(us), [INSERT] 99thPercentileLatency(us), [INSERT] Return=OK]
# Index: []
#
# [0 rows x 22 columns]

# %%
dfobj2
# Out:
#            [OVERALL] RunTime(ms)  [OVERALL] Throughput(ops/sec)  \
# Couchbase                 2141.0                    2335.357310
# 0                         1493.0                    3348.961822
#
#            [READ] Operations  [READ] AverageLatency(us)  \
# Couchbase             4746.0                 465.676991
# 0                     4734.0                 401.171103
#
#            [READ] MinLatency(us)  [READ] MaxLatency(us)  \
# Couchbase                  100.0                28143.0
# 0                          142.0                60223.0
#
#            [READ] 95thPercentileLatency(us)  [READ] 99thPercentileLatency(us)  \
# Couchbase                            1315.0                            5007.0
# 0                                     838.0                            2339.0
#
#            [READ] Return=OK  [CLEANUP] Operations  ...  \
# Couchbase            4746.0                   2.0  ...
# 0                    4734.0                   2.0  ...
#
#            [CLEANUP] MaxLatency(us)  [CLEANUP] 95thPercentileLatency(us)  \
# Couchbase                       1.0                                  1.0
# 0                            5691.0                               5691.0
#
#            [CLEANUP] 99thPercentileLatency(us)  [INSERT] Operations  \
# Couchbase                                  1.0                254.0
# 0                                       5691.0                266.0
#
#            [INSERT] AverageLatency(us)  [INSERT] MinLatency(us)  \
# Couchbase                   852.822835                    254.0
# 0                           642.853383                    233.0
#
#            [INSERT] MaxLatency(us)  [INSERT] 95thPercentileLatency(us)  \
# Couchbase                  13607.0                              1975.0
# 0                          10351.0                              1181.0
#
#            [INSERT] 99thPercentileLatency(us)  [INSERT] Return=OK
# Couchbase                              5207.0               254.0
# 0                                      3189.0               266.0
#
# [2 rows x 22 columns]

# %%
dfobj2.to_csv("newcleaned.csv")

# %%
result.to_csv("cleaned.csv")

# %%
dfnew2 = dfnew.loc[:,["Run:"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-5d72fed308a9> in <module>
# ----> 1 dfnew2 = dfnew.loc[:,["Run:"]]
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     886                 continue
#     887
# --> 888             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     889
#     890         return retval
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1900                     raise ValueError('Cannot index with multidimensional key')
#    1901
# -> 1902                 return self._getitem_iterable(key, axis=axis)
#    1903
#    1904             # nested tuple slicing
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1203             # A collection of keys
#    1204             keyarr, indexer = self._get_listlike_indexer(key, axis,
# -> 1205                                                          raise_missing=False)
#    1206             return self.obj._reindex_with_indexers({axis: [keyarr, indexer]},
#    1207                                                    copy=True, allow_dups=True)
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Run:'], dtype='object')] are in the [columns]"
