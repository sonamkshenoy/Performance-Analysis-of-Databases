# %%
import pandas as pd

# %%
# Read CSV files
file_name = 'summary.txt'
columnNames = ["Operation","Key","Value"]
df = pd.read_csv(file_name,names = columnNames)
# df.columns=["Operation","Key","Value"] Deletes the first row and adds title

# %%
df
# Out:
#     Operation                         Key          Value
# 0   [OVERALL]                 RunTime(ms)    1956.000000
# 1   [OVERALL]         Throughput(ops/sec)    2556.237219
# 2      [READ]                  Operations    5000.000000
# 3      [READ]          AverageLatency(us)     576.477200
# 4      [READ]              MinLatency(us)     148.000000
# 5      [READ]              MaxLatency(us)  132479.000000
# 6      [READ]   95thPercentileLatency(us)    1229.000000
# 7      [READ]   99thPercentileLatency(us)    2471.000000
# 8      [READ]                   Return=OK    5000.000000
# 9   [CLEANUP]                  Operations       2.000000
# 10  [CLEANUP]          AverageLatency(us)     994.500000
# 11  [CLEANUP]              MinLatency(us)       4.000000
# 12  [CLEANUP]              MaxLatency(us)    1985.000000
# 13  [CLEANUP]   95thPercentileLatency(us)    1985.000000
# 14  [CLEANUP]   99thPercentileLatency(us)    1985.000000

# %%
df['Title'] = df["Operation"]+df["Key"]

# %%
df
# Out:
#     Operation                         Key          Value  \
# 0   [OVERALL]                 RunTime(ms)    1956.000000
# 1   [OVERALL]         Throughput(ops/sec)    2556.237219
# 2      [READ]                  Operations    5000.000000
# 3      [READ]          AverageLatency(us)     576.477200
# 4      [READ]              MinLatency(us)     148.000000
# 5      [READ]              MaxLatency(us)  132479.000000
# 6      [READ]   95thPercentileLatency(us)    1229.000000
# 7      [READ]   99thPercentileLatency(us)    2471.000000
# 8      [READ]                   Return=OK    5000.000000
# 9   [CLEANUP]                  Operations       2.000000
# 10  [CLEANUP]          AverageLatency(us)     994.500000
# 11  [CLEANUP]              MinLatency(us)       4.000000
# 12  [CLEANUP]              MaxLatency(us)    1985.000000
# 13  [CLEANUP]   95thPercentileLatency(us)    1985.000000
# 14  [CLEANUP]   99thPercentileLatency(us)    1985.000000
#
#                                   Title
# 0                 [OVERALL] RunTime(ms)
# 1         [OVERALL] Throughput(ops/sec)
# 2                     [READ] Operations
# 3             [READ] AverageLatency(us)
# 4                 [READ] MinLatency(us)
# 5                 [READ] MaxLatency(us)
# 6      [READ] 95thPercentileLatency(us)
# 7      [READ] 99thPercentileLatency(us)
# 8                      [READ] Return=OK
# 9                  [CLEANUP] Operations
# 10         [CLEANUP] AverageLatency(us)
# 11             [CLEANUP] MinLatency(us)
# 12             [CLEANUP] MaxLatency(us)
# 13  [CLEANUP] 95thPercentileLatency(us)
# 14  [CLEANUP] 99thPercentileLatency(us)

# %%
df.set_index("Title",inplace=True)

# %%
df
# Out:
#                                      Operation                         Key  \
# Title
# [OVERALL] RunTime(ms)                [OVERALL]                 RunTime(ms)
# [OVERALL] Throughput(ops/sec)        [OVERALL]         Throughput(ops/sec)
# [READ] Operations                       [READ]                  Operations
# [READ] AverageLatency(us)               [READ]          AverageLatency(us)
# [READ] MinLatency(us)                   [READ]              MinLatency(us)
# [READ] MaxLatency(us)                   [READ]              MaxLatency(us)
# [READ] 95thPercentileLatency(us)        [READ]   95thPercentileLatency(us)
# [READ] 99thPercentileLatency(us)        [READ]   99thPercentileLatency(us)
# [READ] Return=OK                        [READ]                   Return=OK
# [CLEANUP] Operations                 [CLEANUP]                  Operations
# [CLEANUP] AverageLatency(us)         [CLEANUP]          AverageLatency(us)
# [CLEANUP] MinLatency(us)             [CLEANUP]              MinLatency(us)
# [CLEANUP] MaxLatency(us)             [CLEANUP]              MaxLatency(us)
# [CLEANUP] 95thPercentileLatency(us)  [CLEANUP]   95thPercentileLatency(us)
# [CLEANUP] 99thPercentileLatency(us)  [CLEANUP]   99thPercentileLatency(us)
#
#                                              Value
# Title
# [OVERALL] RunTime(ms)                  1956.000000
# [OVERALL] Throughput(ops/sec)          2556.237219
# [READ] Operations                      5000.000000
# [READ] AverageLatency(us)               576.477200
# [READ] MinLatency(us)                   148.000000
# [READ] MaxLatency(us)                132479.000000
# [READ] 95thPercentileLatency(us)       1229.000000
# [READ] 99thPercentileLatency(us)       2471.000000
# [READ] Return=OK                       5000.000000
# [CLEANUP] Operations                      2.000000
# [CLEANUP] AverageLatency(us)            994.500000
# [CLEANUP] MinLatency(us)                  4.000000
# [CLEANUP] MaxLatency(us)               1985.000000
# [CLEANUP] 95thPercentileLatency(us)    1985.000000
# [CLEANUP] 99thPercentileLatency(us)    1985.000000

# %%
dfnew = df.drop([df.columns[0],df.columns[1]], axis=1)

# %%
dfnew = dfnew.loc[columns]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-49b9cc0edd56> in <module>
# ----> 1 dfnew = dfnew.loc[columns]
#
# NameError: name 'columns' is not defined

# %%
dfnew.to_dict()['Value']
dfnewValues = dfnew.to_dict()['Value']

# %%
dfnewValues
# Out:
# {'[OVERALL] RunTime(ms)': 1956.0,
#  '[OVERALL] Throughput(ops/sec)': 2556.237218813906,
#  '[READ] Operations': 5000.0,
#  '[READ] AverageLatency(us)': 576.4772,
#  '[READ] MinLatency(us)': 148.0,
#  '[READ] MaxLatency(us)': 132479.0,
#  '[READ] 95thPercentileLatency(us)': 1229.0,
#  '[READ] 99thPercentileLatency(us)': 2471.0,
#  '[READ] Return=OK': 5000.0,
#  '[CLEANUP] Operations': 2.0,
#  '[CLEANUP] AverageLatency(us)': 994.5,
#  '[CLEANUP] MinLatency(us)': 4.0,
#  '[CLEANUP] MaxLatency(us)': 1985.0,
#  '[CLEANUP] 95thPercentileLatency(us)': 1985.0,
#  '[CLEANUP] 99thPercentileLatency(us)': 1985.0}

# %%
dfnew
# Out:
#                                             Value
# Title
# [OVERALL] RunTime(ms)                 2173.000000
# [OVERALL] Throughput(ops/sec)         2300.966406
# [READ] Operations                     4773.000000
# [READ] AverageLatency(us)              438.252462
# [READ] MinLatency(us)                  117.000000
# [READ] MaxLatency(us)                32239.000000
# [READ] 95thPercentileLatency(us)      1284.000000
# [READ] 99thPercentileLatency(us)      6679.000000
# [READ] Return=OK                      4773.000000
# [CLEANUP] Operations                     2.000000
# [CLEANUP] AverageLatency(us)             1.000000
# [CLEANUP] MinLatency(us)                 0.000000
# [CLEANUP] MaxLatency(us)                 2.000000
# [CLEANUP] 95thPercentileLatency(us)      2.000000
# [CLEANUP] 99thPercentileLatency(us)      2.000000
# [UPDATE] Operations                    227.000000
# [UPDATE] AverageLatency(us)            738.471366
# [UPDATE] MinLatency(us)                207.000000
# [UPDATE] MaxLatency(us)              13295.000000
# [UPDATE] 95thPercentileLatency(us)    2026.000000
# [UPDATE] 99thPercentileLatency(us)    9671.000000
# [UPDATE] Return=OK                     227.000000

# %%
convert = dfnew.iloc[:,0].to_numpy()

# %%
convert.shape
# Out:
# (22,)

# %%
convert = convert.reshape(1,22)

# %%
dfnewConverted = pd.DataFrame(convert, columns = columns)

# %%
dfobj2 = pd.read_csv("cleaned.csv",index_col=0)

# %%
dfobj2
# Out:
#    [OVERALL] RunTime(ms)  [OVERALL] Throughput(ops/sec)  [READ] Operations  \
# 0                 2048.0                     2441.40625             4728.0
#
#    [READ] AverageLatency(us)  [READ] MinLatency(us)  [READ] MaxLatency(us)  \
# 0                 573.467428                  166.0                51679.0
#
#    [READ] 95thPercentileLatency(us)  [READ] 99thPercentileLatency(us)  \
# 0                            1282.0                            2239.0
#
#    [READ] Return=OK  [CLEANUP] Operations  ...  [CLEANUP] MaxLatency(us)  \
# 0            4728.0                   2.0  ...                    2289.0
#
#    [CLEANUP] 95thPercentileLatency(us)  [CLEANUP] 99thPercentileLatency(us)  \
# 0                               2289.0                               2289.0
#
#    [UPDATE] Operations  [UPDATE] AverageLatency(us)  [UPDATE] MinLatency(us)  \
# 0                272.0                  1347.606618                    429.0
#
#    [UPDATE] MaxLatency(us)  [UPDATE] 95thPercentileLatency(us)  \
# 0                  42975.0                              2099.0
#
#    [UPDATE] 99thPercentileLatency(us)  [UPDATE] Return=OK
# 0                              5079.0               272.0
#
# [1 rows x 22 columns]

# %%
dfobj2 = dfobj2.append(result, sort=False)

# %%
result = pd.concat([dfObj,dfnewConverted], sort=False) # First argument has concatenated data

# %%
result
# Out:
#    [OVERALL] RunTime(ms)  [OVERALL] Throughput(ops/sec)  [READ] Operations  \
# 0                 2173.0                    2300.966406             4773.0
#
#    [READ] AverageLatency(us)  [READ] MinLatency(us)  [READ] MaxLatency(us)  \
# 0                 438.252462                  117.0                32239.0
#
#    [READ] 95thPercentileLatency(us)  [READ] 99thPercentileLatency(us)  \
# 0                            1284.0                            6679.0
#
#    [READ] Return=OK  [CLEANUP] Operations  ...  [CLEANUP] MaxLatency(us)  \
# 0            4773.0                   2.0  ...                       2.0
#
#    [CLEANUP] 95thPercentileLatency(us)  [CLEANUP] 99thPercentileLatency(us)  \
# 0                                  2.0                                  2.0
#
#    [UPDATE] Operations  [UPDATE] AverageLatency(us)  [UPDATE] MinLatency(us)  \
# 0                227.0                   738.471366                    207.0
#
#    [UPDATE] MaxLatency(us)  [UPDATE] 95thPercentileLatency(us)  \
# 0                  13295.0                              2026.0
#
#    [UPDATE] 99thPercentileLatency(us)  [UPDATE] Return=OK
# 0                              9671.0               227.0
#
# [1 rows x 22 columns]

# %%
columns = ['[OVERALL] RunTime(ms)',
 '[OVERALL] Throughput(ops/sec)',
 '[READ] Operations',
 '[READ] AverageLatency(us)',
 '[READ] MinLatency(us)',
 '[READ] MaxLatency(us)',
 '[READ] 95thPercentileLatency(us)',
 '[READ] 99thPercentileLatency(us)',
 '[READ] Return=OK',
 '[CLEANUP] Operations',
 '[CLEANUP] AverageLatency(us)',
 '[CLEANUP] MinLatency(us)',
 '[CLEANUP] MaxLatency(us)',
 '[CLEANUP] 95thPercentileLatency(us)',
 '[CLEANUP] 99thPercentileLatency(us)']

# %%
# Creating an empty Dataframe with column names only
dfObj = pd.DataFrame(columns=columns)

# %%
dfObj
# Out:
# Empty DataFrame
# Columns: [[OVERALL] RunTime(ms), [OVERALL] Throughput(ops/sec), [READ] Operations, [READ] AverageLatency(us), [READ] MinLatency(us), [READ] MaxLatency(us), [READ] 95thPercentileLatency(us), [READ] 99thPercentileLatency(us), [READ] Return=OK, [CLEANUP] Operations, [CLEANUP] AverageLatency(us), [CLEANUP] MinLatency(us), [CLEANUP] MaxLatency(us), [CLEANUP] 95thPercentileLatency(us), [CLEANUP] 99thPercentileLatency(us), [UPDATE] Operations, [UPDATE] AverageLatency(us), [UPDATE] MinLatency(us), [UPDATE] MaxLatency(us), [UPDATE] 95thPercentileLatency(us), [UPDATE] 99thPercentileLatency(us), [UPDATE] Return=OK]
# Index: []
#
# [0 rows x 22 columns]

# %%
dfobj2
# Out:
#    [OVERALL] RunTime(ms)  [OVERALL] Throughput(ops/sec)  [READ] Operations  \
# 0                 2048.0                    2441.406250             4728.0
# 0                 2173.0                    2300.966406             4773.0
#
#    [READ] AverageLatency(us)  [READ] MinLatency(us)  [READ] MaxLatency(us)  \
# 0                 573.467428                  166.0                51679.0
# 0                 438.252462                  117.0                32239.0
#
#    [READ] 95thPercentileLatency(us)  [READ] 99thPercentileLatency(us)  \
# 0                            1282.0                            2239.0
# 0                            1284.0                            6679.0
#
#    [READ] Return=OK  [CLEANUP] Operations  ...  [CLEANUP] MaxLatency(us)  \
# 0            4728.0                   2.0  ...                    2289.0
# 0            4773.0                   2.0  ...                       2.0
#
#    [CLEANUP] 95thPercentileLatency(us)  [CLEANUP] 99thPercentileLatency(us)  \
# 0                               2289.0                               2289.0
# 0                                  2.0                                  2.0
#
#    [UPDATE] Operations  [UPDATE] AverageLatency(us)  [UPDATE] MinLatency(us)  \
# 0                272.0                  1347.606618                    429.0
# 0                227.0                   738.471366                    207.0
#
#    [UPDATE] MaxLatency(us)  [UPDATE] 95thPercentileLatency(us)  \
# 0                  42975.0                              2099.0
# 0                  13295.0                              2026.0
#
#    [UPDATE] 99thPercentileLatency(us)  [UPDATE] Return=OK
# 0                              5079.0               272.0
# 0                              9671.0               227.0
#
# [2 rows x 22 columns]

# %%
dfobj2.to_csv("newcleaned.csv")

# %%
result.to_csv("newcleaned.csv")

# %%
dfnew2 = dfnew.loc[:,["Run:"]]
