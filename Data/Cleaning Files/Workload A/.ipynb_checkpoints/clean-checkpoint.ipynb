# %%
import pandas as pd

# %%
# Read CSV files
file_name = 'summary.txt'
columnNames = ["Operation","Key","Value"]
df = pd.read_csv(file_name,names = columnNames)
# df.columns=["Operation","Key","Value"] Deletes the first row and adds title

# %%
df
# Out:
#                                             Operation  \
# 0   mongo client connection created with mongodb:/...
# 1                                           [OVERALL]
# 2                                           [OVERALL]
# 3                             [TOTAL_GCS_PS_Scavenge]
# 4                         [TOTAL_GC_TIME_PS_Scavenge]
# 5                       [TOTAL_GC_TIME_%_PS_Scavenge]
# 6                            [TOTAL_GCS_PS_MarkSweep]
# 7                        [TOTAL_GC_TIME_PS_MarkSweep]
# 8                      [TOTAL_GC_TIME_%_PS_MarkSweep]
# 9                                         [TOTAL_GCs]
# 10                                    [TOTAL_GC_TIME]
# 11                                  [TOTAL_GC_TIME_%]
# 12                                             [READ]
# 13                                             [READ]
# 14                                             [READ]
# 15                                             [READ]
# 16                                             [READ]
# 17                                             [READ]
# 18                                             [READ]
# 19                                          [CLEANUP]
# 20                                          [CLEANUP]
# 21                                          [CLEANUP]
# 22                                          [CLEANUP]
# 23                                          [CLEANUP]
# 24                                          [CLEANUP]
# 25                                           [UPDATE]
# 26                                           [UPDATE]
# 27                                           [UPDATE]
# 28                                           [UPDATE]
# 29                                           [UPDATE]
# 30                                           [UPDATE]
# 31                                           [UPDATE]
#
#                            Key         Value
# 0                          NaN           NaN
# 1                  RunTime(ms)   1957.000000
# 2          Throughput(ops/sec)   2554.931017
# 3                        Count      4.000000
# 4                     Time(ms)     23.000000
# 5                      Time(%)      1.175268
# 6                        Count      0.000000
# 7                     Time(ms)      0.000000
# 8                      Time(%)      0.000000
# 9                        Count      4.000000
# 10                    Time(ms)     23.000000
# 11                     Time(%)      1.175268
# 12                  Operations   2509.000000
# 13          AverageLatency(us)    595.532882
# 14              MinLatency(us)    153.000000
# 15              MaxLatency(us)  70015.000000
# 16   95thPercentileLatency(us)   1539.000000
# 17   99thPercentileLatency(us)   4827.000000
# 18                   Return=OK   2509.000000
# 19                  Operations      2.000000
# 20          AverageLatency(us)    929.500000
# 21              MinLatency(us)      5.000000
# 22              MaxLatency(us)   1854.000000
# 23   95thPercentileLatency(us)   1854.000000
# 24   99thPercentileLatency(us)   1854.000000
# 25                  Operations   2491.000000
# 26          AverageLatency(us)    596.477720
# 27              MinLatency(us)    173.000000
# 28              MaxLatency(us)  72063.000000
# 29   95thPercentileLatency(us)   1605.000000
# 30   99thPercentileLatency(us)   4507.000000
# 31                   Return=OK   2491.000000

# %%
df['Title'] = df["Operation"]+df["Key"]

# %%
df
# Out:
#                                             Operation  \
# 0   mongo client connection created with mongodb:/...
# 1                                           [OVERALL]
# 2                                           [OVERALL]
# 3                             [TOTAL_GCS_PS_Scavenge]
# 4                         [TOTAL_GC_TIME_PS_Scavenge]
# 5                       [TOTAL_GC_TIME_%_PS_Scavenge]
# 6                            [TOTAL_GCS_PS_MarkSweep]
# 7                        [TOTAL_GC_TIME_PS_MarkSweep]
# 8                      [TOTAL_GC_TIME_%_PS_MarkSweep]
# 9                                         [TOTAL_GCs]
# 10                                    [TOTAL_GC_TIME]
# 11                                  [TOTAL_GC_TIME_%]
# 12                                             [READ]
# 13                                             [READ]
# 14                                             [READ]
# 15                                             [READ]
# 16                                             [READ]
# 17                                             [READ]
# 18                                             [READ]
# 19                                          [CLEANUP]
# 20                                          [CLEANUP]
# 21                                          [CLEANUP]
# 22                                          [CLEANUP]
# 23                                          [CLEANUP]
# 24                                          [CLEANUP]
# 25                                           [UPDATE]
# 26                                           [UPDATE]
# 27                                           [UPDATE]
# 28                                           [UPDATE]
# 29                                           [UPDATE]
# 30                                           [UPDATE]
# 31                                           [UPDATE]
#
#                            Key         Value  \
# 0                          NaN           NaN
# 1                  RunTime(ms)   1957.000000
# 2          Throughput(ops/sec)   2554.931017
# 3                        Count      4.000000
# 4                     Time(ms)     23.000000
# 5                      Time(%)      1.175268
# 6                        Count      0.000000
# 7                     Time(ms)      0.000000
# 8                      Time(%)      0.000000
# 9                        Count      4.000000
# 10                    Time(ms)     23.000000
# 11                     Time(%)      1.175268
# 12                  Operations   2509.000000
# 13          AverageLatency(us)    595.532882
# 14              MinLatency(us)    153.000000
# 15              MaxLatency(us)  70015.000000
# 16   95thPercentileLatency(us)   1539.000000
# 17   99thPercentileLatency(us)   4827.000000
# 18                   Return=OK   2509.000000
# 19                  Operations      2.000000
# 20          AverageLatency(us)    929.500000
# 21              MinLatency(us)      5.000000
# 22              MaxLatency(us)   1854.000000
# 23   95thPercentileLatency(us)   1854.000000
# 24   99thPercentileLatency(us)   1854.000000
# 25                  Operations   2491.000000
# 26          AverageLatency(us)    596.477720
# 27              MinLatency(us)    173.000000
# 28              MaxLatency(us)  72063.000000
# 29   95thPercentileLatency(us)   1605.000000
# 30   99thPercentileLatency(us)   4507.000000
# 31                   Return=OK   2491.000000
#
#                                      Title
# 0                                      NaN
# 1                    [OVERALL] RunTime(ms)
# 2            [OVERALL] Throughput(ops/sec)
# 3            [TOTAL_GCS_PS_Scavenge] Count
# 4     [TOTAL_GC_TIME_PS_Scavenge] Time(ms)
# 5    [TOTAL_GC_TIME_%_PS_Scavenge] Time(%)
# 6           [TOTAL_GCS_PS_MarkSweep] Count
# 7    [TOTAL_GC_TIME_PS_MarkSweep] Time(ms)
# 8   [TOTAL_GC_TIME_%_PS_MarkSweep] Time(%)
# 9                        [TOTAL_GCs] Count
# 10                [TOTAL_GC_TIME] Time(ms)
# 11               [TOTAL_GC_TIME_%] Time(%)
# 12                       [READ] Operations
# 13               [READ] AverageLatency(us)
# 14                   [READ] MinLatency(us)
# 15                   [READ] MaxLatency(us)
# 16        [READ] 95thPercentileLatency(us)
# 17        [READ] 99thPercentileLatency(us)
# 18                        [READ] Return=OK
# 19                    [CLEANUP] Operations
# 20            [CLEANUP] AverageLatency(us)
# 21                [CLEANUP] MinLatency(us)
# 22                [CLEANUP] MaxLatency(us)
# 23     [CLEANUP] 95thPercentileLatency(us)
# 24     [CLEANUP] 99thPercentileLatency(us)
# 25                     [UPDATE] Operations
# 26             [UPDATE] AverageLatency(us)
# 27                 [UPDATE] MinLatency(us)
# 28                 [UPDATE] MaxLatency(us)
# 29      [UPDATE] 95thPercentileLatency(us)
# 30      [UPDATE] 99thPercentileLatency(us)
# 31                      [UPDATE] Return=OK

# %%
df.set_index("Title",inplace=True)

# %%
df
# Out:
#                                                                                 Operation  \
# Title
# NaN                                     mongo client connection created with mongodb:/...
# [OVERALL] RunTime(ms)                                                           [OVERALL]
# [OVERALL] Throughput(ops/sec)                                                   [OVERALL]
# [TOTAL_GCS_PS_Scavenge] Count                                     [TOTAL_GCS_PS_Scavenge]
# [TOTAL_GC_TIME_PS_Scavenge] Time(ms)                          [TOTAL_GC_TIME_PS_Scavenge]
# [TOTAL_GC_TIME_%_PS_Scavenge] Time(%)                       [TOTAL_GC_TIME_%_PS_Scavenge]
# [TOTAL_GCS_PS_MarkSweep] Count                                   [TOTAL_GCS_PS_MarkSweep]
# [TOTAL_GC_TIME_PS_MarkSweep] Time(ms)                        [TOTAL_GC_TIME_PS_MarkSweep]
# [TOTAL_GC_TIME_%_PS_MarkSweep] Time(%)                     [TOTAL_GC_TIME_%_PS_MarkSweep]
# [TOTAL_GCs] Count                                                             [TOTAL_GCs]
# [TOTAL_GC_TIME] Time(ms)                                                  [TOTAL_GC_TIME]
# [TOTAL_GC_TIME_%] Time(%)                                               [TOTAL_GC_TIME_%]
# [READ] Operations                                                                  [READ]
# [READ] AverageLatency(us)                                                          [READ]
# [READ] MinLatency(us)                                                              [READ]
# [READ] MaxLatency(us)                                                              [READ]
# [READ] 95thPercentileLatency(us)                                                   [READ]
# [READ] 99thPercentileLatency(us)                                                   [READ]
# [READ] Return=OK                                                                   [READ]
# [CLEANUP] Operations                                                            [CLEANUP]
# [CLEANUP] AverageLatency(us)                                                    [CLEANUP]
# [CLEANUP] MinLatency(us)                                                        [CLEANUP]
# [CLEANUP] MaxLatency(us)                                                        [CLEANUP]
# [CLEANUP] 95thPercentileLatency(us)                                             [CLEANUP]
# [CLEANUP] 99thPercentileLatency(us)                                             [CLEANUP]
# [UPDATE] Operations                                                              [UPDATE]
# [UPDATE] AverageLatency(us)                                                      [UPDATE]
# [UPDATE] MinLatency(us)                                                          [UPDATE]
# [UPDATE] MaxLatency(us)                                                          [UPDATE]
# [UPDATE] 95thPercentileLatency(us)                                               [UPDATE]
# [UPDATE] 99thPercentileLatency(us)                                               [UPDATE]
# [UPDATE] Return=OK                                                               [UPDATE]
#
#                                                                Key  \
# Title
# NaN                                                            NaN
# [OVERALL] RunTime(ms)                                  RunTime(ms)
# [OVERALL] Throughput(ops/sec)                  Throughput(ops/sec)
# [TOTAL_GCS_PS_Scavenge] Count                                Count
# [TOTAL_GC_TIME_PS_Scavenge] Time(ms)                      Time(ms)
# [TOTAL_GC_TIME_%_PS_Scavenge] Time(%)                      Time(%)
# [TOTAL_GCS_PS_MarkSweep] Count                               Count
# [TOTAL_GC_TIME_PS_MarkSweep] Time(ms)                     Time(ms)
# [TOTAL_GC_TIME_%_PS_MarkSweep] Time(%)                     Time(%)
# [TOTAL_GCs] Count                                            Count
# [TOTAL_GC_TIME] Time(ms)                                  Time(ms)
# [TOTAL_GC_TIME_%] Time(%)                                  Time(%)
# [READ] Operations                                       Operations
# [READ] AverageLatency(us)                       AverageLatency(us)
# [READ] MinLatency(us)                               MinLatency(us)
# [READ] MaxLatency(us)                               MaxLatency(us)
# [READ] 95thPercentileLatency(us)         95thPercentileLatency(us)
# [READ] 99thPercentileLatency(us)         99thPercentileLatency(us)
# [READ] Return=OK                                         Return=OK
# [CLEANUP] Operations                                    Operations
# [CLEANUP] AverageLatency(us)                    AverageLatency(us)
# [CLEANUP] MinLatency(us)                            MinLatency(us)
# [CLEANUP] MaxLatency(us)                            MaxLatency(us)
# [CLEANUP] 95thPercentileLatency(us)      95thPercentileLatency(us)
# [CLEANUP] 99thPercentileLatency(us)      99thPercentileLatency(us)
# [UPDATE] Operations                                     Operations
# [UPDATE] AverageLatency(us)                     AverageLatency(us)
# [UPDATE] MinLatency(us)                             MinLatency(us)
# [UPDATE] MaxLatency(us)                             MaxLatency(us)
# [UPDATE] 95thPercentileLatency(us)       95thPercentileLatency(us)
# [UPDATE] 99thPercentileLatency(us)       99thPercentileLatency(us)
# [UPDATE] Return=OK                                       Return=OK
#
#                                                Value
# Title
# NaN                                              NaN
# [OVERALL] RunTime(ms)                    1957.000000
# [OVERALL] Throughput(ops/sec)            2554.931017
# [TOTAL_GCS_PS_Scavenge] Count               4.000000
# [TOTAL_GC_TIME_PS_Scavenge] Time(ms)       23.000000
# [TOTAL_GC_TIME_%_PS_Scavenge] Time(%)       1.175268
# [TOTAL_GCS_PS_MarkSweep] Count              0.000000
# [TOTAL_GC_TIME_PS_MarkSweep] Time(ms)       0.000000
# [TOTAL_GC_TIME_%_PS_MarkSweep] Time(%)      0.000000
# [TOTAL_GCs] Count                           4.000000
# [TOTAL_GC_TIME] Time(ms)                   23.000000
# [TOTAL_GC_TIME_%] Time(%)                   1.175268
# [READ] Operations                        2509.000000
# [READ] AverageLatency(us)                 595.532882
# [READ] MinLatency(us)                     153.000000
# [READ] MaxLatency(us)                   70015.000000
# [READ] 95thPercentileLatency(us)         1539.000000
# [READ] 99thPercentileLatency(us)         4827.000000
# [READ] Return=OK                         2509.000000
# [CLEANUP] Operations                        2.000000
# [CLEANUP] AverageLatency(us)              929.500000
# [CLEANUP] MinLatency(us)                    5.000000
# [CLEANUP] MaxLatency(us)                 1854.000000
# [CLEANUP] 95thPercentileLatency(us)      1854.000000
# [CLEANUP] 99thPercentileLatency(us)      1854.000000
# [UPDATE] Operations                      2491.000000
# [UPDATE] AverageLatency(us)               596.477720
# [UPDATE] MinLatency(us)                   173.000000
# [UPDATE] MaxLatency(us)                 72063.000000
# [UPDATE] 95thPercentileLatency(us)       1605.000000
# [UPDATE] 99thPercentileLatency(us)       4507.000000
# [UPDATE] Return=OK                       2491.000000

# %%
dfnew = df.drop([df.columns[0],df.columns[1]], axis=1)

# %%
dfnew = dfnew.loc[columns]

# %%
dfnew.to_dict()['Value']
dfnewValues = dfnew.to_dict()['Value']

# %%
dfnewValues
# Out:
# {'[OVERALL] RunTime(ms)': 1957.0,
#  '[OVERALL] Throughput(ops/sec)': 2554.9310168625448,
#  '[READ] Operations': 2509.0,
#  '[READ] AverageLatency(us)': 595.5328816261458,
#  '[READ] MinLatency(us)': 153.0,
#  '[READ] MaxLatency(us)': 70015.0,
#  '[READ] 95thPercentileLatency(us)': 1539.0,
#  '[READ] 99thPercentileLatency(us)': 4827.0,
#  '[READ] Return=OK': 2509.0,
#  '[CLEANUP] Operations': 2.0,
#  '[CLEANUP] AverageLatency(us)': 929.5,
#  '[CLEANUP] MinLatency(us)': 5.0,
#  '[CLEANUP] MaxLatency(us)': 1854.0,
#  '[CLEANUP] 95thPercentileLatency(us)': 1854.0,
#  '[CLEANUP] 99thPercentileLatency(us)': 1854.0,
#  '[UPDATE] Operations': 2491.0,
#  '[UPDATE] AverageLatency(us)': 596.4777197912484,
#  '[UPDATE] MinLatency(us)': 173.0,
#  '[UPDATE] MaxLatency(us)': 72063.0,
#  '[UPDATE] 95thPercentileLatency(us)': 1605.0,
#  '[UPDATE] 99thPercentileLatency(us)': 4507.0,
#  '[UPDATE] Return=OK': 2491.0}

# %%
dfnew
# Out:
#                                             Value
# Title
# [OVERALL] RunTime(ms)                 1957.000000
# [OVERALL] Throughput(ops/sec)         2554.931017
# [READ] Operations                     2509.000000
# [READ] AverageLatency(us)              595.532882
# [READ] MinLatency(us)                  153.000000
# [READ] MaxLatency(us)                70015.000000
# [READ] 95thPercentileLatency(us)      1539.000000
# [READ] 99thPercentileLatency(us)      4827.000000
# [READ] Return=OK                      2509.000000
# [CLEANUP] Operations                     2.000000
# [CLEANUP] AverageLatency(us)           929.500000
# [CLEANUP] MinLatency(us)                 5.000000
# [CLEANUP] MaxLatency(us)              1854.000000
# [CLEANUP] 95thPercentileLatency(us)   1854.000000
# [CLEANUP] 99thPercentileLatency(us)   1854.000000
# [UPDATE] Operations                   2491.000000
# [UPDATE] AverageLatency(us)            596.477720
# [UPDATE] MinLatency(us)                173.000000
# [UPDATE] MaxLatency(us)              72063.000000
# [UPDATE] 95thPercentileLatency(us)    1605.000000
# [UPDATE] 99thPercentileLatency(us)    4507.000000
# [UPDATE] Return=OK                    2491.000000

# %%
convert = dfnew.iloc[:,0].to_numpy()

# %%
convert.shape
# Out:
# (22,)

# %%
convert = convert.reshape(1,22)

# %%
dfnewConverted = pd.DataFrame(convert, columns = columns)

# %%
dfobj2 = pd.read_csv("cleaned.csv",index_col=0)

# %%
dfobj2
# Out:
#            [OVERALL] RunTime(ms)  [OVERALL] Throughput(ops/sec)  \
# Couchbase                   2434                    2054.231717
#
#            [READ] Operations  [READ] AverageLatency(us)  \
# Couchbase               2517                 483.284068
#
#            [READ] MinLatency(us)  [READ] MaxLatency(us)  \
# Couchbase                     94                  23359
#
#            [READ] 95thPercentileLatency(us)  [READ] 99thPercentileLatency(us)  \
# Couchbase                              1269                              4843
#
#            [READ] Return=OK  [CLEANUP] Operations  ...  \
# Couchbase              2517                     2  ...
#
#            [CLEANUP] MaxLatency(us)  [CLEANUP] 95thPercentileLatency(us)  \
# Couchbase                         1                                    1
#
#            [CLEANUP] 99thPercentileLatency(us)  [UPDATE] Operations  \
# Couchbase                                    1                 2483
#
#            [UPDATE] AverageLatency(us)  [UPDATE] MinLatency(us)  \
# Couchbase                   533.888844                      104
#
#            [UPDATE] MaxLatency(us)  [UPDATE] 95thPercentileLatency(us)  \
# Couchbase                    38495                                1440
#
#            [UPDATE] 99thPercentileLatency(us)  [UPDATE] Return=OK
# Couchbase                                6083                2483
#
# [1 rows x 22 columns]

# %%
dfobj2 = dfobj2.append(result, sort=False)

# %%
result = pd.concat([dfObj,dfnewConverted], sort=False) # First argument has concatenated data

# %%
result
# Out:
#    [OVERALL] RunTime(ms)  [OVERALL] Throughput(ops/sec)  [READ] Operations  \
# 0                 1957.0                    2554.931017             2509.0
#
#    [READ] AverageLatency(us)  [READ] MinLatency(us)  [READ] MaxLatency(us)  \
# 0                 595.532882                  153.0                70015.0
#
#    [READ] 95thPercentileLatency(us)  [READ] 99thPercentileLatency(us)  \
# 0                            1539.0                            4827.0
#
#    [READ] Return=OK  [CLEANUP] Operations  ...  [CLEANUP] MaxLatency(us)  \
# 0            2509.0                   2.0  ...                    1854.0
#
#    [CLEANUP] 95thPercentileLatency(us)  [CLEANUP] 99thPercentileLatency(us)  \
# 0                               1854.0                               1854.0
#
#    [UPDATE] Operations  [UPDATE] AverageLatency(us)  [UPDATE] MinLatency(us)  \
# 0               2491.0                    596.47772                    173.0
#
#    [UPDATE] MaxLatency(us)  [UPDATE] 95thPercentileLatency(us)  \
# 0                  72063.0                              1605.0
#
#    [UPDATE] 99thPercentileLatency(us)  [UPDATE] Return=OK
# 0                              4507.0              2491.0
#
# [1 rows x 22 columns]

# %%
columns = ['[OVERALL] RunTime(ms)',
 '[OVERALL] Throughput(ops/sec)',
 '[READ] Operations',
 '[READ] AverageLatency(us)',
 '[READ] MinLatency(us)',
 '[READ] MaxLatency(us)',
 '[READ] 95thPercentileLatency(us)',
 '[READ] 99thPercentileLatency(us)',
 '[READ] Return=OK',
 '[CLEANUP] Operations',
 '[CLEANUP] AverageLatency(us)',
 '[CLEANUP] MinLatency(us)',
 '[CLEANUP] MaxLatency(us)',
 '[CLEANUP] 95thPercentileLatency(us)',
 '[CLEANUP] 99thPercentileLatency(us)',
 '[UPDATE] Operations',
 '[UPDATE] AverageLatency(us)',
 '[UPDATE] MinLatency(us)',
 '[UPDATE] MaxLatency(us)',
 '[UPDATE] 95thPercentileLatency(us)',
 '[UPDATE] 99thPercentileLatency(us)',
 '[UPDATE] Return=OK']

# %%
# Creating an empty Dataframe with column names only
dfObj = pd.DataFrame(columns=columns)

# %%
dfObj
# Out:
# Empty DataFrame
# Columns: [[OVERALL] RunTime(ms), [OVERALL] Throughput(ops/sec), [READ] Operations, [READ] AverageLatency(us), [READ] MinLatency(us), [READ] MaxLatency(us), [READ] 95thPercentileLatency(us), [READ] 99thPercentileLatency(us), [READ] Return=OK, [CLEANUP] Operations, [CLEANUP] AverageLatency(us), [CLEANUP] MinLatency(us), [CLEANUP] MaxLatency(us), [CLEANUP] 95thPercentileLatency(us), [CLEANUP] 99thPercentileLatency(us), [UPDATE] Operations, [UPDATE] AverageLatency(us), [UPDATE] MinLatency(us), [UPDATE] MaxLatency(us), [UPDATE] 95thPercentileLatency(us), [UPDATE] 99thPercentileLatency(us), [UPDATE] Return=OK]
# Index: []
#
# [0 rows x 22 columns]

# %%
dfobj2
# Out:
#            [OVERALL] RunTime(ms)  [OVERALL] Throughput(ops/sec)  \
# Couchbase                 2434.0                    2054.231717
# 0                         1957.0                    2554.931017
#
#            [READ] Operations  [READ] AverageLatency(us)  \
# Couchbase             2517.0                 483.284068
# 0                     2509.0                 595.532882
#
#            [READ] MinLatency(us)  [READ] MaxLatency(us)  \
# Couchbase                   94.0                23359.0
# 0                          153.0                70015.0
#
#            [READ] 95thPercentileLatency(us)  [READ] 99thPercentileLatency(us)  \
# Couchbase                            1269.0                            4843.0
# 0                                    1539.0                            4827.0
#
#            [READ] Return=OK  [CLEANUP] Operations  ...  \
# Couchbase            2517.0                   2.0  ...
# 0                    2509.0                   2.0  ...
#
#            [CLEANUP] MaxLatency(us)  [CLEANUP] 95thPercentileLatency(us)  \
# Couchbase                       1.0                                  1.0
# 0                            1854.0                               1854.0
#
#            [CLEANUP] 99thPercentileLatency(us)  [UPDATE] Operations  \
# Couchbase                                  1.0               2483.0
# 0                                       1854.0               2491.0
#
#            [UPDATE] AverageLatency(us)  [UPDATE] MinLatency(us)  \
# Couchbase                   533.888844                    104.0
# 0                           596.477720                    173.0
#
#            [UPDATE] MaxLatency(us)  [UPDATE] 95thPercentileLatency(us)  \
# Couchbase                  38495.0                              1440.0
# 0                          72063.0                              1605.0
#
#            [UPDATE] 99thPercentileLatency(us)  [UPDATE] Return=OK
# Couchbase                              6083.0              2483.0
# 0                                      4507.0              2491.0
#
# [2 rows x 22 columns]

# %%
dfobj2.to_csv("newcleaned.csv")

# %%
dfnew2 = dfnew.loc[:,["Run:"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-5d72fed308a9> in <module>
# ----> 1 dfnew2 = dfnew.loc[:,["Run:"]]
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     886                 continue
#     887
# --> 888             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     889
#     890         return retval
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1900                     raise ValueError('Cannot index with multidimensional key')
#    1901
# -> 1902                 return self._getitem_iterable(key, axis=axis)
#    1903
#    1904             # nested tuple slicing
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1203             # A collection of keys
#    1204             keyarr, indexer = self._get_listlike_indexer(key, axis,
# -> 1205                                                          raise_missing=False)
#    1206             return self.obj._reindex_with_indexers({axis: [keyarr, indexer]},
#    1207                                                    copy=True, allow_dups=True)
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Run:'], dtype='object')] are in the [columns]"
